# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# Pivot Tables

# %%
data = {
'Date': pd.date_range('2023-01-01', periods=20),
'Product': ['A', 'B', 'C', 'D'] * 5,
'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
'Sales': np.random.randint(100, 1000, 20),
'Units': np.random. randint(10, 100, 20),
'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}
df = pd.DataFrame(data)

df ['Month'] = df ['Date'].dt.month_name()
df ['Quarter'] = 'Q' + df ['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    881     95   John  January      Q1
# 1  2023-01-02       B   West    162     51   Mary  January      Q1
# 2  2023-01-03       C  North    880     93    Bob  January      Q1
# 3  2023-01-04       D  South    551     98  Alice  January      Q1
# 4  2023-01-05       A   East    157     84   John  January      Q1
# 5  2023-01-06       B   West    830     21   Mary  January      Q1
# 6  2023-01-07       C  North    366     27    Bob  January      Q1
# 7  2023-01-08       D  South    956     96  Alice  January      Q1
# 8  2023-01-09       A   East    466     42   John  January      Q1
# 9  2023-01-10       B   West    920     33   Mary  January      Q1
# 10 2023-01-11       C  North    204     85    Bob  January      Q1
# 11 2023-01-12       D  South    160     53  Alice  January      Q1
# 12 2023-01-13       A   East    639     27   John  January      Q1
# 13 2023-01-14       B   West    629     17   Mary  January      Q1
# 14 2023-01-15       C  North    493     97    Bob  January      Q1
# 15 2023-01-16       D  South    341     27  Alice  January      Q1
# 16 2023-01-17       A   East    950     58   John  January      Q1
# 17 2023-01-18       B   West    945     27   Mary  January      Q1
# 18 2023-01-19       C  North    772     72    Bob  January      Q1
# 19 2023-01-20       D  South    705     22  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales", index = "Region", columns = "Product")
# Out:
# Product      A      B      C      D
# Region
# East     618.6    NaN    NaN    NaN
# North      NaN    NaN  543.0    NaN
# South      NaN    NaN    NaN  542.6
# West       NaN  697.2    NaN    NaN

# %%
pd.pivot_table(df,values = "Sales", index = "Region", columns = "Product",aggfunc = "median")
# Out:
# Product      A      B      C      D
# Region
# East     639.0    NaN    NaN    NaN
# North      NaN    NaN  493.0    NaN
# South      NaN    NaN    NaN  551.0
# West       NaN  830.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values = ['Sales', 'Units'], index = 'Region', columns = 'Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     618.6    NaN    NaN    NaN  61.2   NaN   NaN   NaN
# North      NaN    NaN  543.0    NaN   NaN   NaN  74.8   NaN
# South      NaN    NaN    NaN  542.6   NaN   NaN   NaN  59.2
# West       NaN  697.2    NaN    NaN   NaN  29.8   NaN   NaN

# %% [markdown]
# Cross Tabs

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
